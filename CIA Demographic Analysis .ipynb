# %% [markdown]
# # Introduction

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect("factbook.db")
cursor = conn.cursor()
q1 = "select * from sqlite_master where type='table';"
pd.read_sql_query(q1,conn)
cursor.execute(q1).fetchall()
# Out:
# [('table',
#   'sqlite_sequence',
#   'sqlite_sequence',
#   3,
#   'CREATE TABLE sqlite_sequence(name,seq)'),
#  ('table',
#   'facts',
#   'facts',
#   47,
#   'CREATE TABLE "facts" ("id" INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, "code" varchar(255) NOT NULL, "name" varchar(255) NOT NULL, "area" integer, "area_land" integer, "area_water" integer, "population" integer, "population_growth" float, "birth_rate" float, "death_rate" float, "migration_rate" float)')]

# %% [markdown]
# # Overview of the Data

# %%
q2 = "select * from facts limit 5"
pd.read_sql_query(q2,conn)
# Out:
#    id code         name     area  area_land  area_water  population  \
# 0   1   af  Afghanistan   652230     652230           0    32564342
# 1   2   al      Albania    28748      27398        1350     3029278
# 2   3   ag      Algeria  2381741    2381741           0    39542166
# 3   4   an      Andorra      468        468           0       85580
# 4   5   ao       Angola  1246700    1246700           0    19625353
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               2.32       38.57       13.89            1.51
# 1               0.30       12.92        6.58            3.30
# 2               1.84       23.67        4.31            0.92
# 3               0.12        8.13        6.96            0.00
# 4               2.78       38.78       11.49            0.46

# %% [markdown]
# # Summary Statistics

# %%
q3 = "select min(population),max(population),min(population_growth),max(population_growth) from facts"
pd.read_sql_query(q3,conn)
# Out:
#    min(population)  max(population)  min(population_growth)  \
# 0                0       7256490011                     0.0
#
#    max(population_growth)
# 0                    4.02

# %% [markdown]
# # Exploring Outliers

# %%
q4 = "select * from facts where population == 0"
pd.read_sql_query(q4,conn)
# Out:
#     id code        name  area  area_land area_water  population  \
# 0  250   ay  Antarctica  None     280000       None           0
#
#   population_growth birth_rate death_rate migration_rate
# 0              None       None       None           None

# %%
q5 = "select * from facts where population == (select max(population) from facts)"
pd.read_sql_query(q5,conn)
# Out:
#     id code   name  area area_land area_water  population  population_growth  \
# 0  261   xx  World  None      None       None  7256490011               1.08
#
#    birth_rate  death_rate migration_rate
# 0        18.6         7.8           None

# %% [markdown]
# # Exploring Average Population and Area

# %%
q6 = "select AVG(population),AVG(area) from facts"
pd.read_sql_query(q6,conn)
# Out:
#    AVG(population)      AVG(area)
# 0     6.209493e+07  555093.546185

# %% [markdown]
# # Finding Densely Populated Countries

# %%
q7 = "select * from facts where population > (select AVG(population) from facts) and area < (select AVG(area) from facts)"
pd.read_sql_query(q7,conn)
# Out:
#     id code            name    area  area_land  area_water  population  \
# 0   14   bg      Bangladesh  148460     130170       18290   168957745
# 1   65   gm         Germany  357022     348672        8350    80854408
# 2   85   ja           Japan  377915     364485       13430   126919659
# 3  138   rp     Philippines  300000     298170        1830   100998376
# 4  173   th        Thailand  513120     510890        2230    67976405
# 5  185   uk  United Kingdom  243610     241930        1680    64088222
# 6  192   vm         Vietnam  331210     310070       21140    94348835
#
#    population_growth  birth_rate  death_rate  migration_rate
# 0               1.60       21.14        5.61            0.46
# 1               0.17        8.47       11.42            1.24
# 2               0.16        7.93        9.51            0.00
# 3               1.61       24.27        6.11            2.09
# 4               0.34       11.19        7.80            0.00
# 5               0.54       12.17        9.35            2.54
# 6               0.97       15.96        5.93            0.30

# %% [markdown]
# # 20 Countries will add the most people to their population next year

# %%
q9 = """select * 
from facts 
where population != 0 and population_growth != 0
order by population * population_growth DESC limit 20"""
pd.read_sql_query(q9,conn)
# Out:
#      id code                               name       area  area_land  \
# 0   261   xx                              World        NaN        NaN
# 1    77   in                              India  3287263.0  2973193.0
# 2    37   ch                              China  9596960.0  9326410.0
# 3   129   ni                            Nigeria   923768.0   910768.0
# 4   132   pk                           Pakistan   796095.0   770875.0
# 5    58   et                           Ethiopia  1104300.0        NaN
# 6    14   bg                         Bangladesh   148460.0   130170.0
# 7   186   us                      United States  9826675.0  9161966.0
# 8    78   id                          Indonesia  1904569.0  1811569.0
# 9    40   cg  Congo, Democratic Republic of the  2344858.0  2267048.0
# 10  138   rp                        Philippines   300000.0   298170.0
# 11   53   eg                              Egypt  1001450.0   995450.0
# 12   24   br                             Brazil  8515770.0  8358140.0
# 13  114   mx                             Mexico  1964375.0  1943945.0
# 14  172   tz                           Tanzania   947300.0   885800.0
# 15  197   ee                     European Union  4324782.0        NaN
# 16  182   ug                             Uganda   241038.0   197100.0
# 17   80   iz                               Iraq   438317.0   437367.0
# 18  179   tu                             Turkey   783562.0   769632.0
# 19   79   ir                               Iran  1648195.0  1531595.0
#
#     area_water  population  population_growth  birth_rate  death_rate  \
# 0          NaN  7256490011               1.08       18.60        7.80
# 1     314070.0  1251695584               1.22       19.55        7.32
# 2     270550.0  1367485388               0.45       12.49        7.53
# 3      13000.0   181562056               2.45       37.64       12.90
# 4      25220.0   199085847               1.46       22.58        6.49
# 5     104300.0    99465819               2.89       37.27        8.19
# 6      18290.0   168957745               1.60       21.14        5.61
# 7     664709.0   321368864               0.78       12.49        8.15
# 8      93000.0   255993674               0.92       16.72        6.37
# 9      77810.0    79375136               2.45       34.88       10.07
# 10      1830.0   100998376               1.61       24.27        6.11
# 11      6000.0    88487396               1.79       22.90        4.77
# 12    157630.0   204259812               0.77       14.46        6.58
# 13     20430.0   121736809               1.18       18.78        5.26
# 14     61500.0    51045882               2.79       36.39        8.00
# 15         NaN   513949445               0.25       10.20       10.20
# 16     43938.0    37101745               3.24       43.79       10.69
# 17       950.0    37056169               2.93       31.45        3.77
# 18     13930.0    79414269               1.26       16.33        5.88
# 19    116600.0    81824270               1.20       17.99        5.94
#
#     migration_rate
# 0              NaN
# 1             0.04
# 2             0.44
# 3             0.22
# 4             1.54
# 5             0.22
# 6             0.46
# 7             3.86
# 8             1.16
# 9             0.27
# 10            2.09
# 11            0.19
# 12            0.14
# 13            1.68
# 14            0.54
# 15            2.50
# 16            0.74
# 17            1.62
# 18            2.16
# 19            0.07

# %% [markdown]
# # 20 Countries have a higher death rate than birth rate

# %%
q10= """select * 
from facts 
where birth_rate != 0 and death_rate != 0 and death_rate > birth_rate
order by birth_rate / death_rate ASC"""
pd.read_sql_query(q10,conn)
# Out:
#      id code                       name      area  area_land  area_water  \
# 0    26   bu                   Bulgaria    110879     108489        2390
# 1   153   ri                     Serbia     77474      77474           0
# 2    96   lg                     Latvia     64589      62249        2340
# 3   102   lh                  Lithuania     65300      62680        2620
# 4    75   hu                    Hungary     93028      89608        3420
# 5   117   mn                     Monaco         2          2           0
# 6   158   si                   Slovenia     20273      20151         122
# 7   183   up                    Ukraine    603550     579330       24220
# 8    65   gm                    Germany    357022     348672        8350
# 9   214   sb  Saint Pierre and Miquelon       242        242           0
# 10  142   ro                    Romania    238391     229891        8500
# 11   44   hr                    Croatia     56594      55974         620
# 12   67   gr                     Greece    131957     130647        1310
# 13   16   bo                    Belarus    207600     202900        4700
# 14   85   ja                      Japan    377915     364485       13430
# 15  140   po                   Portugal     92090      91470         620
# 16  143   rs                     Russia  17098242   16377742      720500
# 17   57   en                    Estonia     45228      42388        2840
# 18   83   it                      Italy    301340     294140        7200
# 19   22   bk     Bosnia and Herzegovina     51197      51187          10
# 20   47   ez             Czech Republic     78867      77247        1620
# 21  116   md                    Moldova     33851      32891         960
# 22  139   pl                     Poland    312685     304255        8430
# 23   10   au                    Austria     83871      82445        1426
#
#     population  population_growth  birth_rate  death_rate  migration_rate
# 0      7186893               0.58        8.92       14.44            0.29
# 1      7176794               0.46        9.08       13.66            0.00
# 2      1986705               1.06       10.00       14.31            6.26
# 3      2884433               1.04       10.10       14.27            6.27
# 4      9897541               0.22        9.16       12.73            1.33
# 5        30535               0.12        6.65        9.24            3.83
# 6      1983412               0.26        8.42       11.37            0.37
# 7     44429471               0.60       10.72       14.46            2.25
# 8     80854408               0.17        8.47       11.42            1.24
# 9         5657               1.08        7.42        9.72            8.49
# 10    21666350               0.30        9.14       11.90            0.24
# 11     4464844               0.13        9.45       12.18            1.39
# 12    10775643               0.01        8.66       11.09            2.32
# 13     9589689               0.20       10.70       13.36            0.70
# 14   126919659               0.16        7.93        9.51            0.00
# 15    10825309               0.09        9.27       11.02            2.67
# 16   142423773               0.04       11.60       13.69            1.69
# 17     1265420               0.55       10.51       12.40            3.60
# 18    61855120               0.27        8.74       10.19            4.10
# 19     3867055               0.13        8.87        9.75            0.38
# 20    10644842               0.16        9.63       10.34            2.33
# 21     3546847               1.03       12.00       12.59            9.67
# 22    38562189               0.09        9.74       10.19            0.46
# 23     8665550               0.55        9.41        9.42            5.56
